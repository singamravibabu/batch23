# %% [markdown]
# # INTRODUCTION TO PANDAS

# %% [markdown]
# - *Pandas* is a Python third-party library to work with tabular data for data analysis
# - Installing pandas, along with numpy:
#
# ```
# pip install numpy pandas
# ```
#
# - To use *pandas* we need to import it:
#     - *import pandas as pd*

# %% [markdown]
# #### In pandas, we work with two types of objects:
#     - Series    - 1D (column)
#     - DataFrame - 2D (rows and columns)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## The Series Object

# %%
# Creating an empty series object
pd.Series()
# Out:
# Series([], dtype: object)

# %%
ice_creams = ["chocolate", "vanilla", "strawberry", "butterscotch", "mint"]
pd.Series(ice_creams)
# Out:
# 0       chocolate
# 1         vanilla
# 2      strawberry
# 3    butterscotch
# 4            mint
# dtype: object

# %%
pd.Series(data=ice_creams)
# Out:
# 0       chocolate
# 1         vanilla
# 2      strawberry
# 3    butterscotch
# 4            mint
# dtype: object

# %%
ice_creams = ["chocolate", "vanilla", "strawberry", "butterscotch", "mint"]
weekdays = ["Mon", "Tue", "Wed", "Thu", "Fri"]
pd.Series(data=ice_creams, index=weekdays)
# Out:
# Mon       chocolate
# Tue         vanilla
# Wed      strawberry
# Thu    butterscotch
# Fri            mint
# dtype: object

# %% [markdown]
# #### Examples of Series'

# %%
scores = [99, 85, 92, 88, 76]
pd.Series(scores)               # pd.Series(data=scores)
# Out:
# 0    99
# 1    85
# 2    92
# 3    88
# 4    76
# dtype: int64

# %%
bool_values = [True, False, True, True, False]
pd.Series(bool_values)         # pd.Series(data=bool_values)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
temps = [36.5, 37.0, 38.2, 39.1, 36.8]
pd.Series(temps)               # pd.Series(data=temps)
# Out:
# 0    36.5
# 1    37.0
# 2    38.2
# 3    39.1
# 4    36.8
# dtype: float64

# %%
cities = ["Hyd", "Blr", "Che", "Tri", "Amr"]
pd.Series(data=cities)
# Out:
# 0    Hyd
# 1    Blr
# 2    Che
# 3    Tri
# 4    Amr
# dtype: object

# %% [markdown]
# ##### Creating a Series with missing values

# %%
temperatures = [36.5, 37.0, 38.2, np.nan, 36.8] # np.nan represents missing value
pd.Series(temperatures)
# Out:
# 0    36.5
# 1    37.0
# 2    38.2
# 3     NaN
# 4    36.8
# dtype: float64

# %% [markdown]
# #### Creating a Series from Python dictionary

# %%
# dictionary
students_pers = {
    "Manu": 85,
    "Ravi": 89,
    "Sujitha": 88,
    "Suryani": 90,
    "Anil": 87
}
pd.Series(students_pers)
# Out:
# Manu       85
# Ravi       89
# Sujitha    88
# Suryani    90
# Anil       87
# dtype: int64

# %% [markdown]
# #### Creating series from a tuple

# %%
sales = (100, 200, 150, 300, 250)
pd.Series(sales)
# Out:
# 0    100
# 1    200
# 2    150
# 3    300
# 4    250
# dtype: int64

# %% [markdown]
# #### Creating a Series from a Set
# - Throws an error
# - Convert the set to list/tuple

# %%
my_set = {"January", "February", "March", "April", "May"}
# pd.Series(my_set)       # Throws an error because sets are unordered
pd.Series(list(my_set))  # Converting set to list before creating Series
# Out:
# 0       March
# 1         May
# 2     January
# 3       April
# 4    February
# dtype: object

# %% [markdown]
# #### A series with random numbers

# %%
random_data = np.random.randint(1, 100, 10)
pd.Series(random_data)
# Out:
# 0    70
# 1    54
# 2    70
# 3    87
# 4    32
# 5    78
# 6    35
# 7    81
# 8    45
# 9    62
# dtype: int32

# %% [markdown]
# ### Series Attribute

# %%
ice_creams = ["chocolate", "vanilla", "strawberry", "butterscotch", "mint"]
weekdays = ["Mon", "Tue", "Wed", "Thu", "Fri"]
diet = pd.Series(data=ice_creams, index=weekdays)
diet
# Out:
# Mon       chocolate
# Tue         vanilla
# Wed      strawberry
# Thu    butterscotch
# Fri            mint
# dtype: object

# %%
# values attribute
diet.values
# Out:
# array(['chocolate', 'vanilla', 'strawberry', 'butterscotch', 'mint'],
#       dtype=object)

# %%
type(diet.values)
# Out:
# numpy.ndarray

# %%
# index attribute
diet.index
# Out:
# Index(['Mon', 'Tue', 'Wed', 'Thu', 'Fri'], dtype='object')

# %%
# dtype for data type of the series
diet.dtype
# Out:
# dtype('O')

# %%
print(diet.dtype)
# Out:
# object

# %%
# size attribute for number of elements in the series
diet.size
# Out:
# 5

# %%
# shape attribute for dimensions of the series
diet.shape
# Out:
# (5,)

# %%
diet.values
# Out:
# array(['chocolate', 'vanilla', 'strawberry', 'butterscotch', 'mint'],
#       dtype=object)

# %%
# is_unique attribute to check if all values are unique
diet.is_unique
# Out:
# True

# %%
# is_unique attribute to check if all values are unique
x = pd.Series([1, 2, 3, 4, 5, 1])
x.is_unique
# Out:
# False

# %%
mt = pd.Series([10, 20, 30, 40, 50])
# is_monotonic attribute to check if values are in increasing order
mt.is_monotonic_increasing
# Out:
# True

# %%
mt.is_monotonic_decreasing
# Out:
# False

# %% [markdown]
# ### Retrieving the First and Last Rows

# %%
values = range(0, 500, 5)
nums = pd.Series(values)
nums
# Out:
# 0       0
# 1       5
# 2      10
# 3      15
# 4      20
#      ...
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# Length: 100, dtype: int64

# %%
# head() / head(n) / head(n=5) method to get first n elements
nums.head()     # first 5 elements by default
# Out:
# 0     0
# 1     5
# 2    10
# 3    15
# 4    20
# dtype: int64

# %%
nums.head(12)   # first 12 elements
# Out:
# 0      0
# 1      5
# 2     10
# 3     15
# 4     20
# 5     25
# 6     30
# 7     35
# 8     40
# 9     45
# 10    50
# 11    55
# dtype: int64

# %%
nums.head(n=3)  # first 3 elements
# Out:
# 0     0
# 1     5
# 2    10
# dtype: int64

# %%
# tail() / tail(n) / tail(n=5) method to get last n elements
nums.tail()     # last 5 elements by default
# Out:
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
nums.tail(n=4)  # last 4 rows
# Out:
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %%
nums.tail(7)    # last 7 elements
# Out:
# 93    465
# 94    470
# 95    475
# 96    480
# 97    485
# 98    490
# 99    495
# dtype: int64

# %% [markdown]
# ## Mathematical Operations

# %% [markdown]
# ### Statistical Operations

# %%
numbers = pd.Series([1, 2, 3, np.nan, 4, 5])
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
print(numbers.count())  # count of non-missing values
# Out:
# 5

# %%
numbers.sum()    # sum of all elements
# Out:
# np.float64(15.0)

# %%
numbers.sum(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.sum(min_count=3)    # sum only if at least 3 non-missing values are present
# Out:
# np.float64(15.0)

# %%
numbers.sum(min_count=6)  # returns NaN since not all values are present
# Out:
# np.float64(nan)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
numbers.product()  # product of all elements
# Out:
# np.float64(120.0)

# %%
numbers.product(skipna=False)
# Out:
# np.float64(nan)

# %%
numbers.product(min_count=3)
# Out:
# np.float64(120.0)

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
# cumsum()  Cumulative sum of elements
numbers.cumsum()
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    10.0
# 5    15.0
# dtype: float64

# %%
numbers.cumsum(skipna=False)
# Out:
# 0    1.0
# 1    3.0
# 2    6.0
# 3    NaN
# 4    NaN
# 5    NaN
# dtype: float64

# %%
numbers
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    5.0
# dtype: float64

# %%
# pct_change() Percentage change between the current and a prior element
numbers.pct_change()
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_18024\384674353.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
# forward fill
# [1, 2, 3, NaN, NaN 4, 5, NaN, 6] -> [1, 2, 3, 3, 3, 4, 5, 5, 6]
# ----- IGNORE ---
# backward fill
# [1, 2, 3, NaN, NaN 4, 5, NaN, 6] -> [1, 2, 3, 4, 4, 4, 5, 6, 6]

# %%
# The following lines below are equivalent: they are forward fill statements
numbers.pct_change()
numbers.pct_change(fill_method="pad")
numbers.pct_change(fill_method="ffill")
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_18024\1157216549.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change()
# C:\Users\singa\AppData\Local\Temp\ipykernel_18024\1157216549.py:3: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method="pad")
# C:\Users\singa\AppData\Local\Temp\ipykernel_18024\1157216549.py:4: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method="ffill")
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.000000
# 4    0.333333
# 5    0.250000
# dtype: float64

# %%
# The following lines below are equivalent: they are backward fill 
numbers.pct_change(fill_method="bfill")
numbers.pct_change(fill_method="backfill")
# Out:
# C:\Users\singa\AppData\Local\Temp\ipykernel_18024\594580177.py:2: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method="bfill")
# C:\Users\singa\AppData\Local\Temp\ipykernel_18024\594580177.py:3: FutureWarning: The 'fill_method' keyword being not None and the 'limit' keyword in Series.pct_change are deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   numbers.pct_change(fill_method="backfill")
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.000000
# 5    0.250000
# dtype: float64

# %%
# mean() Average of all elements
numbers.mean()
# Out:
# np.float64(3.0)

# %%
# median() Median of all elements
numbers.median()
# Out:
# np.float64(3.0)

# %%
# std() Standard deviation of all elements
numbers.std()
# Out:
# np.float64(1.5811388300841898)

# %%
numbers.max()
# Out:
# np.float64(5.0)

# %%
numbers.min()
# Out:
# np.float64(1.0)

# %%
numbers.describe()  # Summary statistics of the series
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
# sample() Random sample of items from an axis of object
numbers.sample(3)   # Returns 3 random elements from the series
# Out:
# 3    NaN
# 5    5.0
# 1    2.0
# dtype: float64

# %%
books = pd.Series(["Attitude", "Caring", "Helping", "Learning", "Caring"])

# %%
# unique() Returns unique values in the series
books.unique()
# Out:
# array(['Attitude', 'Caring', 'Helping', 'Learning'], dtype=object)

# %%
# nunique() Returns number of unique values in the series
books.nunique()
# Out:
# 4

# %% [markdown]
# ### Arithmetic Operations

# %%
s1 = pd.Series(data=[5, np.nan, 15], index=["A", "B", "C"])
s1
# Out:
# A     5.0
# B     NaN
# C    15.0
# dtype: float64

# %%
s1 + 3
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
s1.add(3)
# Out:
# A     8.0
# B     NaN
# C    18.0
# dtype: float64

# %%
# The three lines below are equivalent
s1 - 5
s1.sub(5)
s1.subtract(5)
# Out:
# A     0.0
# B     NaN
# C    10.0
# dtype: float64

# %%
# The three lines below are equivalent
s1 * 3
s1.mul(3)
s1.multiply(3)
# Out:
# A    15.0
# B     NaN
# C    45.0
# dtype: float64

# %%
# The Three lines below are equivalent
s1 / 2
s1.div(2)
s1.divide(2)
# Out:
# A    2.5
# B    NaN
# C    7.5
# dtype: float64

# %%
# The two lines below are equivalent
s1 // 2
s1.floordiv(2)
# Out:
# A    2.0
# B    NaN
# C    7.0
# dtype: float64

# %%
# The two lines below are equivalent
s1 % 3
s1.mod(3)
# Out:
# A    2.0
# B    NaN
# C    0.0
# dtype: float64

# %% [markdown]
# ### Broadcasting

# %%
s1 = pd.Series(data=[1, 2, 3], index=["A", "B", "C"])
s2 = pd.Series(data=[4, 5, 6], index=["B", "A", "C"])
s1 + s2
# Out:
# A    6
# B    6
# C    9
# dtype: int64

# %%
s1 = pd.Series(data=[1, 2, np.nan, 3], index=["A", "B", "C", "D"])
s2 = pd.Series(data=[1, 5, np.nan, 3], index=["A", "B", "C", "D"])
s1 == s2
# Out:
# A     True
# B    False
# C    False
# D     True
# dtype: bool

# %%
s1 = pd.Series(data=[1, 2, 3], index=["A", "B", "C"])
s2 = pd.Series(data=[4, 5, 6, 7], index=["B", "C", "D", "E"])
s1 + s2
# Out:
# A    NaN
# B    6.0
# C    8.0
# D    NaN
# E    NaN
# dtype: float64

# %% [markdown]
# ### Functions of a Series object

# %%
cities = pd.Series(["Hyd", "Blr", "Che", "Tri", "Amr", np.nan])

# %%
len(cities)
# Out:
# 6

# %%
print(dir(cities))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__static_attributes__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_agg_examples_doc', '_agg_see_also_doc', '_align_for_op', '_align_frame', '_align_series', '_append', '_arith_method', '_as_manager', '_attrs', '_binop', '_can_hold_na', '_check_inplace_and_allows_duplicate_labels', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_result', '_constructor', '_constructor_expanddim', '_constructor_expanddim_from_mgr', '_constructor_from_mgr', '_data', '_deprecate_downcast', '_dir_additions', '_dir_deletions', '_drop_axis', '_drop_labels_or_levels', '_duplicated', '_find_valid_index', '_flags', '_flex_method', '_from_mgr', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_cleaned_column_resolvers', '_get_index_resolvers', '_get_label_or_level_values', '_get_numeric_data', '_get_rows_with_mask', '_get_value', '_get_values_tuple', '_get_with', '_getitem_slice', '_gotitem', '_hidden_attrs', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_dict', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_cached', '_is_copy', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_is_view_after_cow_rules', '_item_cache', '_ixs', '_logical_func', '_logical_method', '_map_values', '_maybe_update_cacher', '_memory_usage', '_metadata', '_mgr', '_min_count_stat_function', '_name', '_needs_reindex_multi', '_pad_or_backfill', '_protect_consolidate', '_reduce', '_references', '_reindex_axes', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_rename', '_replace_single', '_repr_data_resource_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_labels', '_set_name', '_set_value', '_set_values', '_set_with', '_set_with_engine', '_shift_with_freq', '_slice', '_stat_function', '_stat_function_ddof', '_take_with_is_copy', '_to_latex_via_styler', '_typ', '_update_inplace', '_validate_dtype', '_values', '_where', 'abs', 'add', 'add_prefix', 'add_suffix', 'agg', 'aggregate', 'align', 'all', 'any', 'apply', 'argmax', 'argmin', 'argsort', 'array', 'asfreq', 'asof', 'astype', 'at', 'at_time', 'attrs', 'autocorr', 'axes', 'backfill', 'between', 'between_time', 'bfill', 'bool', 'case_when', 'clip', 'combine', 'combine_first', 'compare', 'convert_dtypes', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cump ...
