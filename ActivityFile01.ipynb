# %% [markdown]
# # Activity 01 - Literals and Operators

# %%
100 # integer literal
# Out:
# 100

# %%
-50 # integer literal
# Out:
# -50

# %%
0 # integer literal
# Out:
# 0

# %%
-10.001 # floating-point number
# Out:
# -10.001

# %%
0.0 # floating-point number
# Out:
# 0.0

# %%
50.1234
# Out:
# 50.1234

# %%
'hello' # string literal
# Out:
# 'hello'

# %%
"goodbye"
# Out:
# 'goodbye'

# %% [markdown]
# NOTE: Using inconsistent quotes throws an exception:
# - 'hello"
# - "goodbye'

# %%
""  # empty string
# Out:
# ''

# %%
'' # empty string
# Out:
# ''

# %%
"3489"
# Out:
# '3489'

# %%
"""This is a multi-line string.
This is second line of the string.
And this is the last/third line of the string."""
# Out:
# 'This is a multi-line string.\nThis is second line of the string.\nAnd this is the last/third line of the string.'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + 100
# Out:
# 101

# %%
False + 100
# Out:
# 100

# %%
None

# %% [markdown]
# ### Arithmetic Operators

# %%
100 + 200   # addition
# Out:
# 300

# %%
200 - 50    # subtraction
# Out:
# 150

# %%
30 * 50     # multiplication
# Out:
# 1500

# %%
27 / 4
# Out:
# 6.75

# %%
27 // 4
# Out:
# 6

# %%
27 % 4
# Out:
# 3

# %%
625 ** 625
# Out:
# ...

# %% [markdown]
# ### Comparison / Relational / Boolean Operators

# %%
100 > 50
# Out:
# True

# %%
200 < 100
# Out:
# False

# %%
50 == 50.0
# Out:
# True

# %%
100 == 55
# Out:
# False

# %%
80 != 18
# Out:
# True

# %%
1000 >= 111
# Out:
# True

# %%
500 <= 12
# Out:
# False
